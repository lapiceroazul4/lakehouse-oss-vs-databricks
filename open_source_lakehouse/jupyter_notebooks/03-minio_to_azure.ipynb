# %%
from azure.storage.blob import BlobServiceClient
from dlt.sources.filesystem  import readers

import dlt
import os

# %%
# Configura tu pipeline
pipeline = dlt.pipeline(
    pipeline_name="minio_to_azure",
    destination="filesystem",
    dataset_name="taxis_parquet_data",
)

# %%
parquet_reader = readers(
    bucket_url="s3://my-bucket/taxis/taxis_iceberg_5128d68f-aa5c-4270-a561-d530f60229b4/data",
    file_glob="*.parquet"
).read_parquet()

parquet_reader = parquet_reader.with_name("df_parquet")

# %%
# Ejecuta el pipeline
load_info = pipeline.run(
    parquet_reader,
    loader_file_format="parquet",
    write_disposition="replace"
)

print(load_info)
print(pipeline.last_trace.last_normalize_info)
# Out:
# Pipeline minio_to_azure load step completed in 3 minutes and 16.32 seconds
# 1 load package(s) were loaded to destination filesystem and into dataset dimelo_flow
# The filesystem destination used abfss://clase-4-dlt@fhbd.dfs.core.windows.net/GRUPO_6 location to store data
# Load package 1757139071.3071916 is LOADED and contains no failed jobs
# Normalized data for the following tables:
# - df_parquet: 3475226 row(s)
# - _dlt_pipeline_state: 1 row(s)
#
# Load package 1757139071.3071916 is NORMALIZED and NOT YET LOADED to the destination and contains no failed jobs

# %% [markdown]
# ## Confirmar subida del archivo en bucket de Azure

# %%
# Configuración desde variables de entorno
ACCOUNT_NAME = os.getenv("AZURE_STORAGE_ACCOUNT_NAME")
ACCOUNT_KEY = os.getenv("AZURE_STORAGE_ACCOUNT_KEY")
CONTAINER_NAME = os.getenv("AZURE_CONTAINER_NAME")

def list_azure_blobs():
    """Lista todos los blobs del contenedor"""
    try:
        # Crear cliente
        blob_service_client = BlobServiceClient(
            account_url=f"https://{ACCOUNT_NAME}.blob.core.windows.net",
            credential=ACCOUNT_KEY
        )
        
        # Obtener contenedor
        container_client = blob_service_client.get_container_client(CONTAINER_NAME)
        
        # Listar blobs
        print(f"Objetos en el contenedor '{CONTAINER_NAME}':")
        print("-" * 50)
        
        for i, blob in enumerate(container_client.list_blobs(), 1):
            size_mb = blob.size / (1024 * 1024)
            print(f"{i:3d}. {blob.name} ({size_mb:.2f} MB)")
        
    except Exception as e:
        print(f"Error: {e}")



def delete_dimelo_flow():
    """Elimina todos los blobs dentro de GRUPO_6/dimelo_flow/ y luego los directorios"""
    try:
        blob_service_client = BlobServiceClient(
            account_url=f"https://{ACCOUNT_NAME}.blob.core.windows.net",
            credential=ACCOUNT_KEY
        )
        container_client = blob_service_client.get_container_client(CONTAINER_NAME)

        prefix = "GRUPO_6/dimelo_flow/"
        blobs_to_delete = list(container_client.list_blobs(name_starts_with=prefix))

        deleted = 0
        for blob in blobs_to_delete:
            print(f"Eliminando blob: {blob.name}")
            container_client.delete_blob(blob.name)
            deleted += 1

        print(f"✅ Eliminados {deleted} blobs bajo {prefix}")

        # Intentar borrar el directorio si existe (solo si usas ADLS Gen2 con HNS)
        try:
            from azure.storage.filedatalake import DataLakeServiceClient

            dl_service = DataLakeServiceClient(
                account_url=f"https://{ACCOUNT_NAME}.dfs.core.windows.net",
                credential=ACCOUNT_KEY
            )
            file_system_client = dl_service.get_file_system_client(CONTAINER_NAME)

            # Borrar la carpeta raíz
            dir_client = file_system_client.get_directory_client(prefix.rstrip("/"))
            dir_client.delete_directory()
            print(f"✅ Carpeta {prefix} eliminada")
        except ImportError:
            print("ℹ️ Solo se borraron los blobs (no el directorio). Instala azure-storage-file-datalake si quieres borrar carpetas con HNS.")

    except Exception as e:
        print(f"Error al eliminar: {e}")

# %%
list_azure_blobs()
# Out:
# Objetos en el contenedor 'clase-4-dlt':
# --------------------------------------------------
#   1. GRUPO_1 (0.00 MB)
#   2. GRUPO_1/taxis_parquet (0.00 MB)
#   3. GRUPO_1/taxis_parquet/_dlt_loads (0.00 MB)
#   4. GRUPO_1/taxis_parquet/_dlt_loads/s3_to_adls__1757702839.136807.jsonl (0.00 MB)
#   5. GRUPO_1/taxis_parquet/_dlt_loads/s3_to_adls__1757720850.1673822.jsonl (0.00 MB)
#   6. GRUPO_1/taxis_parquet/_dlt_pipeline_state (0.00 MB)
#   7. GRUPO_1/taxis_parquet/_dlt_pipeline_state/s3_to_adls__1757702839.136807__b04e1cc0d4556f1be45152bbf8b5d0d5847d9aa52a60eaed4c438141a24c0c7c.jsonl (0.00 MB)
#   8. GRUPO_1/taxis_parquet/_dlt_version (0.00 MB)
#   9. GRUPO_1/taxis_parquet/_dlt_version/s3_to_adls__1757702843.589799__b04e1cc0d4556f1be45152bbf8b5d0d5847d9aa52a60eaed4c438141a24c0c7c.jsonl (0.00 MB)
#  10. GRUPO_1/taxis_parquet/_dlt_version/s3_to_adls__1757721258.7429767__5d45807d5aae2793a12fa1caf5e477d22cd3f3e13e05f4b5f20e6bee79451e32.jsonl (0.01 MB)
#  11. GRUPO_1/taxis_parquet/df_parquet (0.00 MB)
#  12. GRUPO_1/taxis_parquet/df_parquet/1757720850.1673822.c278209d43.parquet (138.83 MB)
#  13. GRUPO_1/taxis_parquet/init (0.00 MB)
#  14. GRUPO_1/yellow_trip_20250910112135 (0.00 MB)
#  15. GRUPO_1/yellow_trip_20250910112135/yellow_trip_data (0.00 MB)
#  16. GRUPO_1/yellow_trip_20250910112135/yellow_trip_data/1757546495.2376165.503b80e90a.parquet (68.76 MB)
#  17. GRUPO_2 (0.00 MB)
#  18. GRUPO_2/grupo_2_parquet (0.00 MB)
#  19. GRUPO_2/grupo_2_parquet/_dlt_loads (0.00 MB)
#  20. GRUPO_2/grupo_2_parquet/_dlt_loads/s3_to_adls__1757558201.2186682.jsonl (0.00 MB)
#  21. GRUPO_2/grupo_2_parquet/_dlt_pipeline_state (0.00 MB)
#  22. GRUPO_2/grupo_2_parquet/_dlt_pipeline_state/s3_to_adls__1757558201.2186682__91a25dc1ed5d5efd8a7dd72a0b641c88428e82efe6f578ffec33f6a003cdfec7.jsonl (0.00 MB)
#  23. GRUPO_2/grupo_2_parquet/_dlt_version (0.00 MB)
#  24. GRUPO_2/grupo_2_parquet/_dlt_version/s3_to_adls__1757558718.3029258__91a25dc1ed5d5efd8a7dd72a0b641c88428e82efe6f578ffec33f6a003cdfec7.jsonl (0.01 MB)
#  25. GRUPO_2/grupo_2_parquet/init (0.00 MB)
#  26. GRUPO_2/grupo_2_parquet/parquet_files (0.00 MB)
#  27. GRUPO_2/grupo_2_parquet/parquet_files/1757558201.2186682.97eb1ee240.jsonl.gz (134.13 MB)
#  28. GRUPO_3 (0.00 MB)
#  29. GRUPO_3/taxis_parquet (0.00 MB)
#  30. GRUPO_3/taxis_parquet/_dlt_loads (0.00 MB)
#  31. GRUPO_3/taxis_parquet/_dlt_loads/s3_to_adls__1757555279.8299358.jsonl (0.00 MB)
#  32. GRUPO_3/taxis_parquet/_dlt_pipeline_state (0.00 MB)
#  33. GRUPO_3/taxis_parquet/_dlt_pipeline_state/s3_to_adls__1757555279.8299358__d8d2785fc9b5b31085d01e27e48921736c806032e33f1f58ea2274f434c45ed2.jsonl (0.00 MB)
#  34. GRUPO_3/taxis_parquet/_dlt_version (0.00 MB)
#  35. GRUPO_3/taxis_parquet/_dlt_version/s3_to_adls__1757555866.7303457__d8d2785fc9b5b31085d01e27e48921736c806032e33f1f58ea2274f434c45ed2.jsonl (0.01 MB)
#  36. GRUPO_3/taxis_parquet/init (0.00 MB)
#  37. GRUPO_3/taxis_parquet/taxis_data (0.00 MB)
#  38. GRUPO_3/taxis_parquet/taxis_data/1757555279.8299358.0c15d97554.parquet (140.35 MB)
#  39. GRUPO_4 (0.00 MB)
#  40. GRUPO_4/azure (0.00 MB)
#  41. GRUPO_4/azure/_dlt_loads (0.00 MB)
#  42. GRUPO_4/azure/_dlt_loads/s3_to_adls__1757549419.5251415.jsonl (0.00 MB)
#  43. GRUPO_4/azure/_dlt_loads/s3_to_adls__1757561534.6311665.jsonl (0.00 MB)
#  44. GRUPO_4/azure/_dlt_pipeline_state (0.00 MB)
#  45. GRUPO_4/azure/_dlt_pipeline_state/s3_to_adls__1757549419.5251415__490f5a0815bc65bf246a6252df667c15822a2438d49f3eac5139f86149916c56.jsonl (0.00 MB)
#  46. GRUPO_4/azure/_dlt_version (0.00 MB)
#  47. GRUPO_4/azure/_dlt_version/s3_to_adls__1757549424.4517694__490f5a0815bc65bf246a6252df667c15822a2438d49f3eac5139f86149916c56.jsonl (0.00 MB)
#  48. GRUPO_4/azure/init (0.00 MB)
#  49. GRUPO_4/azure/taxis (0.00 MB)
#  50. GRUPO_4/azure/taxis/1757561534.6311665.8211d098cc.parquet (70.52 MB)
#  51. GRUPO_5 (0.00 MB)
#  52. GRUPO_5/taxis_adls (0.00 MB)
#  53. GRUPO_5/taxis_adls/_dlt_loads (0.00 MB)
#  54. GRUPO_5/taxis_adls/_dlt_loads/s3_to_adls__1757635082.6422622.jsonl (0.00 MB)
#  55. GRUPO_5/taxis_adls/_dlt_pipeline_state (0.00 MB)
#  56. GRUPO_5/taxis_adls/_dlt_pipeline_state/s3_to_adls__1757635082.6422622__a477065a1e8126683e2a9fcd6bda1691ab2b35c9c7423e4ab5201b1431c8ea3a.jsonl (0.00 MB)
#  57. GRUPO_5/taxis_adls/_dlt_version (0.00 MB)
#  58. GRUPO_5/taxis_adls/_dlt_version/s3_to_adls__1757635086.8678954__a477065a1e8126683e2a9fcd6bda1691ab2b35c9c7423e4ab5201b1431c8ea3a.jsonl (0.00 MB)
#  59. GRUPO_5/taxis_adls/df_data (0.00 MB)
#  60. GRUPO_5/taxis_adls/df_data/1757635082.6422622.cb00900262.parquet (0.00 MB)
#  61. GRUPO_5/taxis_adls/init (0.00 MB)
#  62. GRUPO_6 (0.00 MB)
#  63. GRUPO_6/dimelo_flow (0.00 MB)
#  64. GRUPO_6/dimelo_flow/_dlt_loads (0.00 MB)
#  65. GRUPO_6/dimelo_flow/_dlt_loads/minio_to_azure__1757139071.3071916.jsonl (0.00 MB)
#  66. GRUPO_6/dimelo_flow/_dlt_loads/minio_to_azure__1757473777.758944.jsonl (0.00 MB)
#  67. GRUPO_6/dimelo_flow/_dlt_pipeline_state (0.00 MB)
#  68. GRUPO_6/dimelo_flow/_dlt_pipeline_state/minio_to_azure__1757139071.3071916__294134021028353b99eb89d13521c215be766effa2581eb8c8d814269c8f2262.jsonl (0.00 MB)
#  69. GRUPO_6/dimelo_flow/_dlt_version (0.00 MB)
#  70. GRUPO_6/dimelo_flow/_dlt_version/minio_to_azure__1757139428.2860715__294134021028353b99eb89d13521c215be766effa2581eb8c8d814269c8f2262.jsonl (0.01 MB)
#  71. GRUPO_6/dimelo_flow/df_parquet (0.00 MB)
#  72. GRUPO_6/dimelo_flow/df_parquet/1757473777.758944.c2df30f895.parquet (0.00 MB)
#  73. GRUPO_6/dimelo_flow/init (0.00 MB)
#  74. GRUPO_6/taxis_parquet_data (0.00 MB)
#  75. GRUPO_6/taxis_parquet_data/_dlt_loads (0.00 MB)
#  76. GRUPO_6/taxis_parquet_data/_dlt_loads/init (0.00 MB)
#  77. GRUPO_6/taxis_parquet_data/_dlt_loads/s3_to_adls__1757470895.9563327.jsonl (0.00 MB)
#  78. GRUPO_6/taxis_parquet_data/_dlt_pipeline_state (0.00 MB)
#  79. GRUPO_6/taxis_parquet_data/_dlt_pipeline_state/init (0.00 MB)
#  80. GRUPO_6/taxis_parquet_data/_dlt_pipeline_state/s3_to_adls__1757470895.9563327__d8aadbd1a3f7bcc3e180e09b770252cf5b722a34d0f2cb759e0cebadf0942eb3.jsonl (0.00 MB)
#  81. GRUPO_6/taxis_parquet_data/_dlt_version (0.00 MB)
#  82. GRUPO_6/taxis_parquet_data/_dlt_version/init (0.00 MB)
#  83. GRUPO_6/taxis_parquet_data/_dlt_version/s3_to_adls__1757471839.2030842__d8aadbd1a3f7bcc3e180e09b770252cf5b722a34d0f2cb759e0cebadf0942eb3.jsonl (0.01 MB)
#  84. GRUPO_6/taxis_parquet_data/df_taxis_parquet (0.00 MB)
#  85. GRUPO_6/taxis_parquet_data/df_taxis_parquet/1757470895.9563327.7dfb223aa1.parquet (140.35 MB)
#  86. GRUPO_6/taxis_parquet_data/init (0.00 MB)
#  87. GRUPO_7 (0.00 MB)
#  88. GRUPO_7/taxis_parquet_data (0.00 MB)
#  89. GRUPO_7/taxis_parquet_data/_dlt_loads (0.00 MB)
#  90. GRUPO_7/taxis_parquet_data/_dlt_loads/init (0.00 MB)
#  91. GRUPO_7/taxis_parquet_data/_dlt_loads/s3_to_adls__1757548639.3819382.jsonl (0.00 MB)
#  92. GRUPO_7/taxis_parquet_data/_dlt_loads/s3_to_adls__1757549295.626075.jsonl (0.00 MB)
#  93. GRUPO_7/taxis_parquet_data/_dlt_pipeline_state (0.00 MB)
#  94. GRUPO_7/taxis_parquet_data/_dlt_pipeline_state/init (0.00 MB)
#  95. GRUPO_7/taxis_parquet_data/_dlt_pipeline_state/s3_to_adls__1757548639.3819382__d8aadbd1a3f7bcc3e180e09b770252cf5b722a34d0f2cb759e0cebadf0942eb3.jsonl (0.00 MB)
#  96. GRUPO_7/taxis_parquet_data/_dlt_version (0.00 MB)
#  97. GRUPO_7/taxis_parquet_data/_dlt_version/init (0.00 MB)
#  98. GRUPO_7/taxis_parquet_data/_dlt_version/s3_to_adls__1757549111.6367931__d8aadbd1a3f7bcc3e180e09b770252cf5b722a34d0f2cb759e0cebadf0942eb3.jsonl (0.01 MB)
#  99. GRUPO_7/taxis_parquet_data/df_taxis_parquet (0.00 MB)
# 100. GRUPO_7/taxis_parquet_data/df_taxis_parquet/1757549295.626075.d16ee3cb87.parquet (140.34 MB)
# 101. GRUPO_7/taxis_parquet_data/init (0.00 MB)
# 102. GRUPO_X (0.00 MB)
# 103. GRUPO_X/raw (0.00 MB)
# 104. GRUPO_X/raw/yellow_tripdata_2025-01.parquet (56.42 MB)
# 105. GRUPO_X/taxis_adls (0.00 MB)
# 106. GRUPO_X/taxis_adls/_dlt_loads (0.00 MB)
# 107. GRUPO_X/taxis_adls/_dlt_loads/s3_to_adls__1757537293.7063005.jsonl (0.00 MB)
# 108. GRUPO_X/taxis_adls/_dlt_pipeline_state (0.00 MB)
# 109. GRUPO_X/taxis_adls/_dlt_pipeline_state/s3_to_adls__1757537293.7063005__a477065a1e8126683e2a9fcd6bda1691ab2b35c9c7423e4ab5201b1431c8ea3a.jsonl (0.00 MB)
# 110. GRUPO_X/taxis_adls/_dlt_version (0.00 MB)
# 111. GRUPO_X/taxis_adls/_dlt_version/s3_to_adls__1757537296.991126__a477065a1e8126683e2a9fcd6bda1691ab2b35c9c7423e4ab5201b1431c8ea3a.jsonl (0.00 MB)
# 112. GRUPO_X/taxis_adls/df_data (0.00 MB)
# 113. GRUPO_X/taxis_adls/df_data/1757537293.7063005.0afc302b9f.parquet (0.00 MB)
# 114. GRUPO_X/taxis_adls/init (0.00 MB)
# 115. airbyte (0.00 MB)
